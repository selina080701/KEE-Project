# %%
import pandas as pd

df = pd.read_csv('movie_conversations_complete.csv', sep=';')

# %%
movies = df['movieTitle'].unique().tolist()
print(len(movies))
print(movies)
# Out:
# 617
# ...

# %%
# extract columns: movieID;movieTitle;movieYear;IMDBrating;IMDBvotes;genre

extracted_df = df[['movieID', 'movieTitle', 'movieYear', 'IMDBrating', 'IMDBvotes', 'genre']].drop_duplicates()

extracted_df.to_csv('movies.csv', index=False, sep=';')
